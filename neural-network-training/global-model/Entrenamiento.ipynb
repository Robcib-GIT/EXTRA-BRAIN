# %%
import torch

# Verificar si la GPU está disponible en PyTorch
print("¿CUDA está disponible?", torch.cuda.is_available())

# Obtener el nombre de la GPU si está disponible
if torch.cuda.is_available():
    print("Nombre de la GPU:", torch.cuda.get_device_name(0))
# Out:
# ¿CUDA está disponible? True
# Nombre de la GPU: Tesla T4

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
#Pip install method (recommended)

# !pip install ultralytics
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.148 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.9/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HbpFNNL8Vo8qbYsgKWFk")
project = rf.workspace("latas-u97yx").project("combination-idxrt")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to combination-1 in yolov8:: 100%|██████████| 21682/21682 [00:04<00:00, 4545.96it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8m-seg.pt data={dataset.location}/data.yaml epochs=500 imgsz=800 batch=8 workers=8 plots=True
# Out:
# /content
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=segment' model. Ignoring 'task=detect' and updating to 'task=segment' to match model.
# Ultralytics 8.3.148 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r train1.zip runs/segment/train
# Out:
#   adding: runs/segment/train6/ (stored 0%)
#   adding: runs/segment/train6/MaskF1_curve.png (deflated 6%)
#   adding: runs/segment/train6/train_batch1.jpg (deflated 4%)
#   adding: runs/segment/train6/BoxR_curve.png (deflated 7%)
#   adding: runs/segment/train6/results.csv (deflated 62%)
#   adding: runs/segment/train6/BoxP_curve.png (deflated 5%)
#   adding: runs/segment/train6/weights/ (stored 0%)
#   adding: runs/segment/train6/weights/last.pt (deflated 8%)
#   adding: runs/segment/train6/weights/best.pt (deflated 8%)
#   adding: runs/segment/train6/MaskR_curve.png (deflated 7%)
#   adding: runs/segment/train6/val_batch1_pred.jpg (deflated 7%)
#   adding: runs/segment/train6/labels.jpg (deflated 22%)
#   adding: runs/segment/train6/BoxPR_curve.png (deflated 11%)
#   adding: runs/segment/train6/MaskPR_curve.png (deflated 10%)
#   adding: runs/segment/train6/val_batch0_labels.jpg (deflated 9%)
#   adding: runs/segment/train6/confusion_matrix_normalized.png (deflated 16%)
# ...

# %%
from google.colab import files
files.download('train1.zip')
